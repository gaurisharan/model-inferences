# %%
import torch
from transformers import pipeline

generate_text = pipeline(model="databricks/dolly-v2-3b", torch_dtype=torch.bfloat16, trust_remote_code=True, device_map="auto")
# Out:
# instruct_pipeline.py:   0%|          | 0.00/9.16k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/databricks/dolly-v2-3b:
# - instruct_pipeline.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# pytorch_model.bin:   0%|          | 0.00/5.68G [00:00<?, ?B/s]
# The `GPTNeoXSdpaAttention` class is deprecated in favor of simply modifying the `config._attn_implementation`attribute of the `GPTNeoXAttention` class! It will be removed in v4.48
# tokenizer_config.json:   0%|          | 0.00/450 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/228 [00:00<?, ?B/s]
# Device set to use cpu

# %%
res = generate_text("Explain to me the difference between nuclear fission and fusion.")
print(res[0]["generated_text"])
# Out:
# Nuclear fission occurs when an atom or atomic nucleus splits in two, releasing energy equivalent to that released when a coal or oil fired steam engine discharges 50 to 100 pounds of TNT.
#
# Nuclear fusion occurs when two or more atoms or atomic nuclei join to form a larger atom or atom. This process releases much less energy than nuclear fission. Most of the energy released in fusion comes from the rapid motion of charged particles called neutrons.
#
# The amount of fusion energy that could be produced is enormous. When the Sun uses up all the hydrogen in the earth's upper atmosphere to fuel its fusion reactions, a massive amount of fusion power would be released.

# %%
res = generate_text("Who is Narendra Modi?")
print(res[0]["generated_text"])
# Out:
# Narendra Modi is an Indian politician who has governed the state of Gujarat in the west. He is the 14th and present Chief Minister of Gujarat. Before becoming the chief minister of Gujarat, Modi was the prime minister of India between 2000 and 2001. In Gujarat, Modi has implemented several development programs and has also helped create several projects. He is a member of the Bharatiya Janata Party (BJP) political party and has been the chief minister of Gujarat since 2001.
