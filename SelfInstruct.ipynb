# %% [markdown]
# <a href="https://colab.research.google.com/github/gaurisharan/model-inferences/blob/main/SelfInstruct.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("text-generation", model="allenai/open-instruct-self-instruct-7b")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# config.json:   0%|          | 0.00/531 [00:00<?, ?B/s]
# pytorch_model.bin.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# ...
# pytorch_model-00001-of-00003.bin:   0%|          | 0.00/9.88G [00:00<?, ?B/s]
# pytorch_model-00002-of-00003.bin:   0%|          | 0.00/9.89G [00:00<?, ?B/s]
# pytorch_model-00003-of-00003.bin:   0%|          | 0.00/7.18G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/132 [00:00<?, ?B/s]
# ...

# %%
res = pipe("What's the difference between classification and regression in machine learning?")
print(res[0]["generated_text"])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-0430638cca79> in <cell line: 0>()
# ----> 1 res = pipe("What's the difference between classification and regression in machine learning?")
#       2 print(res[0]["generated_text"])
#
# /usr/local/lib/python3.11/dist-packages/transformers/pipelines/text_generation.py in __call__(self, text_inputs, **kwargs)
#     283                     else:
#     284                         return super().__call__(list(chats), **kwargs)
# --> 285         return super().__call__(text_inputs, **kwargs)
#     286
#     287     def preprocess(
#
# /usr/local/lib/python3.11/dist-packages/transformers/pipelines/base.py in __call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1360             )
#    1361         else:
# ...

# %%
#generation took more than 45 minutes, stopped with keyboard interrupt
